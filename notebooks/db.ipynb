# %%
import pandas as pd
from sqlalchemy import create_engine

database = "../db/subway.db"

engine = create_engine(f"sqlite:///{database}")

query = "SELECT * FROM stations JOIN station_routes ON stations.station_id = station_routes.station_id"
df = pd.read_sql(query, engine)

print(df.to_string())
# Out:
#      station_id station_name_kr  route_id  station_id  line_id station_code                     road_address admin_dong_code admin_dong_name        lat         lon
# 0             1              서울         1           1        1          150       서울특별시 중구 세종대로 지하2(남대문로 5가)      1114054000             회현동  37.554648  126.972559
# 1             2              시청         2           2        1          151          서울특별시 중구 세종대로 지하101(정동)      1114052000             소공동  37.564718  126.977108
# 2             3              종각         3           3        1          152          서울특별시 종로구 종로 지하55(종로1가)      1111061500     종로1.2.3.4가동  37.570161  126.982923
# 3             4            종로3가         4           4        1          153         서울특별시 종로구 종로 지하129(종로3가)      1111061500     종로1.2.3.4가동  37.571607  126.991806
# 4             5            종로5가         5           5        1          154         서울특별시 종로구 종로 지하216(종로5가)      1111063000         종로5.6가동  37.570926  127.001849
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

database = "../db/subway.db"

engine = create_engine(f"sqlite:///{database}")

query = "SELECT * FROM Dong_Workplace_Population"
df = pd.read_sql(query, engine)

print(df.to_string())

# %%
import pandas as pd
from sqlalchemy import create_engine

database = "../db/subway.db"

engine = create_engine(f"sqlite:///{database}")

# query = "SELECT * FROM Dong_Estimated_Revenue LIMIT 10"
query = "SELECT COUNT(*) FROM Dong_Estimated_Revenue"
df = pd.read_sql(query, engine)

print(df)

# %%
import pandas as pd
from sqlalchemy import create_engine

database = "../db/subway.db"

engine = create_engine(f"sqlite:///{database}")

# query = "SELECT * FROM Dong_Estimated_Revenue LIMIT 10"
query = "SELECT COUNT(*) FROM Impact_Analysis_OptionA"
df = pd.read_sql(query, engine)

print(df)
# Out:
#    COUNT(*)
# 0      1474
