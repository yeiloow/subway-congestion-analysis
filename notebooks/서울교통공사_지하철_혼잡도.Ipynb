# %%
import pandas as pd

df_2023 = pd.read_csv("../data/01_raw/서울교통공사_지하철혼잡도정보_20231231.csv")
df_2024_03 = pd.read_csv("../data/01_raw/서울교통공사_지하철혼잡도정보_20240331.csv")
df_2024_06 = pd.read_csv("../data/01_raw/서울교통공사_지하철혼잡도정보_20240630.csv")

# s1 = df_2023[['역번호', '출발역']].drop_duplicates().assign(dataset='2023')
# s2 = df_2024_03[['역번호', '출발역']].drop_duplicates().assign(dataset='2024_03')
# s3 = df_2024_06[['역번호', '출발역']].drop_duplicates().assign(dataset='2024_06')
# # 모든 데이터를 하나로 합치기
# combined = pd.concat([s1, s2, s3])
# # 1. 역번호는 같은데 출발역 이름이 변경된 경우 확인
# # (예: 뚝섬유원지 -> 자양(뚝섬한강공원))
# diff_names = combined.groupby('역번호')['출발역'].unique()
# changed_names = diff_names[diff_names.apply(len) > 1]
# print("=== 역번호는 같으나 역명이 다른 경우 (변경 이력) ===")
# for station_id, names in changed_names.items():
#     print(f"역번호 {station_id}: {names}")
